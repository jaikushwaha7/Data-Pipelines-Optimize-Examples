# %% [markdown]
# # Why snippets matter for data scince
#
# It helps to stramline processes created and habit of loading code that are helpful in different situatiions from loading csv files to visualizing data.

# %% [markdown]
# ## 1. Loading Multiple files

# %%
import glob
import pandas as pd 
#csv_files = glob.glob('path/to/folder/with/csvs/*.csv')
csv_files = glob.glob('D:\Study\python\Optimize Data Pipelines\*.csv')
# dfs = [pd.read_csv(filename) for filename in csv_files]
dfs = [pd.read_csv(filename) for filename in csv_files]

# %%
type(dfs)
# Out:
# list

# %%
dfs[1]
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
dfs[0]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## 2. Getting unique values froam a column table

# %%
import pandas as pd
# df = pd.read_csv('path/to/folder/with/csvs/*.csv')
df = pd.read_csv('auto-mpg.csv')
# df['Item_Identifier'].unique()
var = 'cylinders'
print('Unique '+ var +':',df[var].unique()) # Values
print('Count of unique '+ var+':',df[var].nunique() )# count
# Out:
# Unique cylinders: [8 4 6 3 5]
# Count of unique cylinders: 5

# %% [markdown]
# ## 3. Display pandas dataframes side by side

# %%
from IPython.display import display_html
from itertools import chain, cycle

def side_by_side(*args, titles=cycle([''])):
    # source: https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side
    html_str=''
    for df, title in zip(args, chain(titles,cycle(['</br>']))):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+="<br>"
        html_str+=f'<h2>{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)
df1 = pd.read_csv("cancer.csv")
df1= df1.iloc[:,:5]
df2 = pd.read_csv("heart.csv")
df2= df2.iloc[:,:5]
display_side_by_side(df1.head(),df2.head(), titles=['Cancer Data','Heart Data'])
### Output)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><br><h2>Cancer Data</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>diagnosis</th>
#       <th>radius_mean</th>
#       <th>texture_mean</th>
#       <th>perimeter_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>842302</td>
#       <td>M</td>
#       <td>17.99</td>
#       <td>10.38</td>
#       <td>122.80</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>842517</td>
#       <td>M</td>
#       <td>20.57</td>
#       <td>17.77</td>
#       <td>132.90</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>84300903</td>
#       <td>M</td>
#       <td>19.69</td>
#       <td>21.25</td>
#       <td>130.00</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>84348301</td>
#       <td>M</td>
#       <td>11.42</td>
#       <td>20.38</td>
# ...

# %% [markdown]
# ## 4. Remove NAN from the dataframe

# %%
df = pd.DataFrame(dict(a=[1,2,3,None]))
df
df1=df.dropna()
display_side_by_side(df.head(),df1.head(), titles=['NA Data','Without NA Data'])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><br><h2>NA Data</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><br><h2>Without NA Data</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>a</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2.0</td>
#     </tr>
#     <tr>
# ...
